# %%
import pandas as pd
df=pd.read_csv('windows_log.csv',index_col=False)
# Out:
# C:\Users\MADHUMITA\AppData\Local\Temp\ipykernel_17348\2285996903.py:2: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df=pd.read_csv('windows_log.csv',index_col=False)

# %%
df.head()
# Out:
#      Level        Date and Time                            Source  Event ID  \
# 0  Warning  13-07-2026 22:14:57  Microsoft-Windows-DistributedCOM     10016
# 1  Warning  13-07-2026 22:14:57  Microsoft-Windows-DistributedCOM     10016
# 2  Warning  13-07-2026 22:14:57  Microsoft-Windows-DistributedCOM     10016
# 3  Warning  13-07-2026 22:14:57  Microsoft-Windows-DistributedCOM     10016
# 4  Warning  13-07-2026 22:14:55  Microsoft-Windows-DistributedCOM     10016
#
#   Task Category
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df.columns
# Out:
# Index(['Level', 'Date and Time', 'Source', 'Event ID', 'Task Category'], dtype='object')

# %%
df
# Out:
#                        Level                               Date and Time  \
# Warning  13-07-2026 22:14:57            Microsoft-Windows-DistributedCOM
# Warning  13-07-2026 22:14:57            Microsoft-Windows-DistributedCOM
# Warning  13-07-2026 22:14:57            Microsoft-Windows-DistributedCOM
# Warning  13-07-2026 22:14:57            Microsoft-Windows-DistributedCOM
# Warning  13-07-2026 22:14:55            Microsoft-Windows-DistributedCOM
# ...                      ...                                         ...
# Warning  09-02-2025 21:46:50  Microsoft-Windows-User Device Registration
# Error    09-02-2025 21:37:44              Microsoft-Windows-PrintService
# Error    09-02-2025 21:37:44              Microsoft-Windows-PrintService
# Error    09-02-2025 21:37:44              Microsoft-Windows-PrintService
# Error    09-02-2025 21:37:44              Microsoft-Windows-PrintService
#
#          Source                     Event ID  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9624 entries, Warning to Error
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Level          9624 non-null   object
#  1   Date and Time  9624 non-null   object
#  2   Source         9624 non-null   int64
#  3   Event ID       2458 non-null   object
#  4   Task Category  9624 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 451.1+ KB

# %%
df.groupby('Level')['Task Category'].sum()
# Out:
# Level
# 01-01-2026 20:16:38    Windows Hello for Business provisioning will n...
# 01-01-2026 20:16:53    Session "Cloud Files Diagnostic Event Listener...
# 01-01-2026 20:36:50    Session "PerfDiag Logger" stopped due to the f...
# 01-01-2026 23:21:58    Windows Hello for Business provisioning will n...
# 01-01-2026 23:22:14    Session "Cloud Files Diagnostic Event Listener...
#                                              ...
# 31-10-2025 11:16:06    Session "PerfDiag Logger" stopped due to the f...
# 31-10-2025 11:26:44    Session "Cloud Files Diagnostic Event Listener...
# 31-12-2025 10:19:03    Windows Hello for Business provisioning will n...
# 31-12-2025 10:19:11    Session "ReadyBoot" stopped due to the followi...
# 31-12-2025 10:19:23    Session "Cloud Files Diagnostic Event Listener...
# Name: Task Category, Length: 6094, dtype: object

# %%
df['Level']
# Out:
# Warning    13-07-2026 22:14:57
# Warning    13-07-2026 22:14:57
# Warning    13-07-2026 22:14:57
# Warning    13-07-2026 22:14:57
# Warning    13-07-2026 22:14:55
#                   ...
# Warning    09-02-2025 21:46:50
# Error      09-02-2025 21:37:44
# Error      09-02-2025 21:37:44
# Error      09-02-2025 21:37:44
# Error      09-02-2025 21:37:44
# Name: Level, Length: 9624, dtype: object

# %%
df.columns
# Out:
# Index(['Level', 'Date and Time', 'Source', 'Event ID', 'Task Category'], dtype='object')

# %%
df
# Out:
#         Level        Date and Time  \
# 0     Warning  13-07-2026 22:14:57
# 1     Warning  13-07-2026 22:14:57
# 2     Warning  13-07-2026 22:14:57
# 3     Warning  13-07-2026 22:14:57
# 4     Warning  13-07-2026 22:14:55
# ...       ...                  ...
# 9619  Warning  09-02-2025 21:46:50
# 9620    Error  09-02-2025 21:37:44
# 9621    Error  09-02-2025 21:37:44
# 9622    Error  09-02-2025 21:37:44
# 9623    Error  09-02-2025 21:37:44
#
#                                           Source  Event ID  \
# 0               Microsoft-Windows-DistributedCOM     10016
# 1               Microsoft-Windows-DistributedCOM     10016
# 2               Microsoft-Windows-DistributedCOM     10016
# 3               Microsoft-Windows-DistributedCOM     10016
# 4               Microsoft-Windows-DistributedCOM     10016
# ...                                          ...       ...
# 9619  Microsoft-Windows-User Device Registration       360
# ...

# %%
df[['Level','Date and Time']]
# Out:
#                        Level                               Date and Time
# Warning  13-07-2026 22:14:57            Microsoft-Windows-DistributedCOM
# Warning  13-07-2026 22:14:57            Microsoft-Windows-DistributedCOM
# Warning  13-07-2026 22:14:57            Microsoft-Windows-DistributedCOM
# Warning  13-07-2026 22:14:57            Microsoft-Windows-DistributedCOM
# Warning  13-07-2026 22:14:55            Microsoft-Windows-DistributedCOM
# ...                      ...                                         ...
# Warning  09-02-2025 21:46:50  Microsoft-Windows-User Device Registration
# Error    09-02-2025 21:37:44              Microsoft-Windows-PrintService
# Error    09-02-2025 21:37:44              Microsoft-Windows-PrintService
# Error    09-02-2025 21:37:44              Microsoft-Windows-PrintService
# Error    09-02-2025 21:37:44              Microsoft-Windows-PrintService
#
# [9624 rows x 2 columns]

# %%
df['Event ID']
# Out:
# 0       10016
# 1       10016
# 2       10016
# 3       10016
# 4       10016
#         ...
# 9619      360
# 9620      318
# 9621      318
# 9622      318
# 9623      215
# Name: Event ID, Length: 9624, dtype: int64

# %%
df.groupby("Event ID")[["Level","Task Category"]].sum()
# Out:
#                                                       Level  \
# Event ID
# 0                       WarningWarningWarningWarningWarning
# 1         WarningErrorErrorErrorWarningErrorWarningError...
# 2         ErrorErrorErrorErrorErrorErrorErrorErrorErrorE...
# 3         ErrorErrorErrorErrorErrorErrorErrorErrorErrorE...
# 4         WarningWarningWarningWarningWarningWarningWarn...
# ...                                                     ...
# 10010     ErrorErrorErrorErrorErrorErrorErrorErrorErrorE...
# 10016     WarningWarningWarningWarningWarningWarningWarn...
# 10024     WarningWarningWarningWarningWarningWarningWarn...
# 10317     ErrorErrorErrorErrorErrorErrorErrorErrorErrorE...
# 16385                                               Warning
#
#                                               Task Category
# Event ID
# 0                                                         0
# 1         LoggingLoggingLoggingLoggingLoggingLoggingLogg...
# ...

# %%
df.groupby("Task Category")
# Out:
#                                                                                Level  \
# Task Category
# (1)                                ErrorErrorErrorErrorErrorErrorErrorErrorErrorE...
# (1014)                             WarningWarningWarningWarningWarningWarningWarn...
# (5000)                                                          ErrorErrorErrorError
# (6)                                ErrorErrorErrorErrorErrorErrorErrorErrorErrorE...
# (63)                               CriticalCriticalCriticalCriticalCriticalCritic...
# (7000)                                                                         Error
# Adding a printer driver                                              ErrorErrorError
# Address Configuration State Event  WarningWarningWarningErrorWarningWarningWarnin...
# Application Crashing Events        ErrorErrorErrorErrorErrorErrorErrorErrorErrorE...
# Gatherer                           WarningWarningWarningWarningWarningWarningWarn...
# ...

# %%
module_df=df.groupby("Task Category").agg({"Level":lambda x:' | '.join(x.unique()),
                                 "Date and Time":lambda y:' | '.join(y.astype(str).unique()),
                                 "Source":lambda p:' | '.join(p.unique()), 
                                 "Event ID":lambda q:' | '.join(q.astype(str).unique())
                                })

# %%
df["Event ID"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Date and Time"].isnull().sum()
# Out:
# np.int64(0)

# %%
module_df
# Out:
#                                              Level  \
# Task Category
# (1)                                          Error
# (1014)                                     Warning
# (5000)                                       Error
# (6)                                          Error
# (63)                                      Critical
# (7000)                                       Error
# Adding a printer driver                      Error
# Address Configuration State Event  Warning | Error
# Application Crashing Events                  Error
# Gatherer                                   Warning
# Hanging Events                               Error
# Installing a printer driver                  Error
# Logging                                    Warning
# PnP                                          Error
# Search service                             Warning
# Session                                      Error
# Surprise Removal                           Warning
# ...

# %%
module_df.to_csv("Module_log.csv")

# %%
df
# Out:
#         Level        Date and Time  \
# 0     Warning  13-07-2026 22:14:57
# 1     Warning  13-07-2026 22:14:57
# 2     Warning  13-07-2026 22:14:57
# 3     Warning  13-07-2026 22:14:57
# 4     Warning  13-07-2026 22:14:55
# ...       ...                  ...
# 9619  Warning  09-02-2025 21:46:50
# 9620    Error  09-02-2025 21:37:44
# 9621    Error  09-02-2025 21:37:44
# 9622    Error  09-02-2025 21:37:44
# 9623    Error  09-02-2025 21:37:44
#
#                                           Source  Event ID  \
# 0               Microsoft-Windows-DistributedCOM     10016
# 1               Microsoft-Windows-DistributedCOM     10016
# 2               Microsoft-Windows-DistributedCOM     10016
# 3               Microsoft-Windows-DistributedCOM     10016
# 4               Microsoft-Windows-DistributedCOM     10016
# ...                                          ...       ...
# 9619  Microsoft-Windows-User Device Registration       360
# ...

# %%
module_df["Frequency"]=df['Task Category'].value_counts()

# %% [markdown]
# module_df

# %%
module_df
# Out:
#                                              Level  Frequency  \
# Task Category
# (1)                                          Error         12
# (1014)                                     Warning         58
# (5000)                                       Error          4
# (6)                                          Error         12
# (63)                                      Critical         17
# (7000)                                       Error          1
# Adding a printer driver                      Error          3
# Address Configuration State Event  Warning | Error        143
# Application Crashing Events                  Error         20
# Gatherer                                   Warning         48
# Hanging Events                               Error         91
# Installing a printer driver                  Error          1
# Logging                                    Warning        612
# PnP                                          Error        173
# ...

# %%
col_ord=['Level','Frequency','Date and Time','Source','Event ID']

# %%
module_df=module_df[col_ord]

# %%
from sklearn.datasets import load_iris
iris=load_iris()
print(iris.feature_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
print(iris.DESCR)

# %%
from sklearn.model_selection import train_test_split
X=iris.data
y=iris.target
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn import tree
model=tree.DecisionTreeClassifier()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
tree.plot_tree(model.fit(X_train,y_train))
# Out:
# [Text(0.4, 0.9, 'x[3] <= 0.8\ngini = 0.665\nsamples = 120\nvalue = [36, 42, 42]'),
#  Text(0.3, 0.7, 'gini = 0.0\nsamples = 36\nvalue = [36, 0, 0]'),
#  Text(0.35, 0.8, 'True  '),
#  Text(0.5, 0.7, 'x[3] <= 1.65\ngini = 0.5\nsamples = 84\nvalue = [0, 42, 42]'),
#  Text(0.45, 0.8, '  False'),
#  Text(0.2, 0.5, 'x[2] <= 4.95\ngini = 0.127\nsamples = 44\nvalue = [0, 41, 3]'),
#  Text(0.1, 0.3, 'gini = 0.0\nsamples = 40\nvalue = [0, 40, 0]'),
#  Text(0.3, 0.3, 'x[3] <= 1.55\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.2, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.4, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8, 0.5, 'x[2] <= 4.85\ngini = 0.049\nsamples = 40\nvalue = [0, 1, 39]'),
#  Text(0.7, 0.3, 'x[1] <= 3.1\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.6, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.8, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
# ...

# %%
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay
rep=classification_report(y_test,y_pred,output_dict=True)

# %%
print(acc)
# Out:
# 0.9333333333333333

# %%
import pandas as pd
rep_df=pd.DataFrame(rep)
rep_df
# Out:
#               0      1      2  accuracy  macro avg  weighted avg
# precision   1.0  0.875  0.875  0.933333   0.916667      0.933333
# recall      1.0  0.875  0.875  0.933333   0.916667      0.933333
# f1-score    1.0  0.875  0.875  0.933333   0.916667      0.933333
# support    14.0  8.000  8.000  0.933333  30.000000     30.000000

# %%
type(rep)
# Out:
# dict

# %%
rep
# Out:
# {'0': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 14.0},
#  '1': {'precision': 0.875, 'recall': 0.875, 'f1-score': 0.875, 'support': 8.0},
#  '2': {'precision': 0.875, 'recall': 0.875, 'f1-score': 0.875, 'support': 8.0},
#  'accuracy': 0.9333333333333333,
#  'macro avg': {'precision': 0.9166666666666666,
#   'recall': 0.9166666666666666,
#   'f1-score': 0.9166666666666666,
#   'support': 30.0},
#  'weighted avg': {'precision': 0.9333333333333333,
#   'recall': 0.9333333333333333,
#   'f1-score': 0.9333333333333333,
#   'support': 30.0}}

# %%
con_mat=confusion_matrix(y_test,y_pred)

# %%
disp=ConfusionMatrixDisplay(con_mat)

# %%
disp.plot()

# %%
con_mat
# Out:
# array([[14,  0,  0],
#        [ 0,  7,  1],
#        [ 0,  1,  7]])
